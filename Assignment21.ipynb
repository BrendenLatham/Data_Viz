# %% [markdown]
# <a href="https://colab.research.google.com/github/BrendenLatham/Data_Viz/blob/main/Assignment21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 21

# %% [markdown]
# John Snow's map of cholera outbreak in 1854 shows graphical excellence in multiple different ways. John Snow used a simple streat plan and clusters of black exes and dots to lead the viewer to draw their own conclusion on the most likely origin of the cholera outbreak. In using this simple format he cut streight to the point and avoided distractions and distortions. He was able to represent hundreds of deaths in a small area relative to each other based on the pumps they were close to. The only explenation needed was the key for shapes and distances.

# %% [markdown]
# For the next part I will be looking at a graph over airplane incidents

# %% [markdown]
# ![economist-safer-skies.png](data:image/png;base64,...)

# %% [markdown]
# I beleive the above graph demostrates graphical excellence. I shows two different points of data plotted against each other in an easy to read way, while also revealing the different verieties of one type of data. It presents data from 1970 to 2012, and gives the generel behavior of the data as time passes. It serves a very clear, stated, purpose.
