# %% [markdown]
# <a href="https://colab.research.google.com/github/BrendenLatham/Data_Viz/blob/main/TwitterScrape.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Twitter scrape

# %%
# !pip install twitter
# Out:
# Collecting twitter
#   Downloading twitter-1.19.3-py2.py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 4.8 MB/s
# Installing collected packages: twitter
# Successfully installed twitter-1.19.3

# %% [markdown]
# For this assignment I will be scraping twitter with my professor's keys

# %%
import twitter
import config

CONSUMER_KEY = config.CONSUMER_KEY
CONSUMER_SECRET = config.CONSUMER_SECRET
OAUTH_TOKEN = config.OAUTH_TOKEN
OAUTH_TOKEN_SECRET = config.OAUTH_TOKEN_SECRET
auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                           CONSUMER_KEY, CONSUMER_SECRET)

mathcs_twitter_api = twitter.Twitter(auth=auth)

# %% [markdown]
# Now let's see what the world is talking about

# %%
WorldTrends = mathcs_twitter_api.trends.place(_id=1)
for i in range(10):
  print(WorldTrends[0]['trends'][i]['query'])
# Out:
# %23JohnsonOut14
# %23akaryak%C4%B1t
# %23isolitiignoti
# %23UltimateSummit4
# Notifications
# %23TPMP
# %22Keir+Starmer%22
# Euphoria
# Sercan
# %22J%C3%83O+NO+PODDELAS%22

# %% [markdown]
# Now I will look for the tweets talking about the upcoming Kentucky Derby

# %%
import json

# %%
q = '#KentuckyDerby'
count = 1000
results = mathcs_twitter_api.search.tweets(q=q, count=count)

# %%
import time

# %%
status = results['statuses']
for _ in range(5):
    print("Length of statuses", len(statuses))
    try:
        next_results = results['search_metadata']['next_results']
    except KeyError:
        break
  
    kwargs = dict([ kv.split('=') for kv in next_results[1:].split("&") ])
    
    results = mathcs_twitter_api.search.tweets(**kwargs)
    statuses += results['statuses']
# Out:
# Length of statuses 200

# %%
text = [status['text'] for status in statuses]
words = [w for t in text for w in t.split()]
tweet = ''
for i in range(0,len(text),1):
  tweet = tweet + text[i]

# %%
freq = {}
for word in words:
  if (word in freq):
    freq[word] +=1
  else:
    freq[word] = 1

# %%
words = sorted(freq, key=freq.get, reverse=True)
words
# Out:
# ['RT',
#  '@rpmhg:',
#  'the',
#  'The',
#  'of',
#  'THE',
#  'A',
#  '#KentuckyDerby',
#  'for',
#  '#ThisRacingLife',
#  'in',
#  'Derby',
#  'Stakes',
#  'en',
#  'out',
#  'Latest',
#  'Hats:',
#  '(Price:',
#  'most',
#  'TO',
#  'SOFTWARE!!',
#  'to',
#  'Check',
#  'el',
#  'and',
#  'our',
#  'on',
#  'a',
#  '-',
#  'la',
#  'Robert',
#  'Lewis',
#  '#horseracing',
#  '&amp;',
#  'this',
#  'know',
#  'y',
#  'B.',
#  'Failsworth',
#  'Millinery',
#  'Lost',
#  'Taulbot',
#  'Method.',
#  '@rpmhg',
#  'account',
#  'other',
#  'horseracing',
#  'products!',
#  'Get',
#  '#Kentuck…',
#  'with',
#  'Speed',
#  'Maps',
#  'USA',
#  'advanced',
#  'pace',
#  'positioning',
#  'profit',
#  'machine',
#  'business',
#  'races',
#  'Just',
#  'DAVID',
#  'POWERS’',
#  'POWER',
#  'HANDICAPPING!!',
#  'GUIDE',
#  'SUCCESS',
#  'FOR',
#  'ASPIRING',
#  'PRO!',
#  'NOW',
#  'ON',
#  'WATCH',
#  'Jeff',
#  'Sillifant’s',
#  '2020',
#  'Race',
#  'Odyssey',
#  'from',
#  'one',
#  'prolific',
#  'Racetrack',
#  'author',
#  '15',
#  '@hats_4u:',
#  'Max',
#  'Ellie',
#  'Events',
#  'Disc',
#  'at',
#  'Holy',
#  'Bull',
#  'Furlong',
#  'Equation',
#  'now',
#  'Software',
#  'Targeting',
#  'high',
#  'percentage',
#  'situations',
#  'sprint',
#  'DENNY',
#  'NASH’S',
#  'REBOUND',
#  'SYSTEM!!',
#  'CONSISTENT',
#  'HIGH',
#  'AVERAGE',
#  'WIN',
#  'MUTUELS!',
#  'SHOWS',
#  'SOLID',
#  'POSITIVE',
#  'ROI',
#  'OVER',
#  '3-1/2',
#  'https://t.co/qteW3M2eN8',
#  '#wed…',
#  '2M2P',
#  'Complete',
#  '‘Suite’',
#  'Handicapping',
#  'Power',
#  'Products',
#  '–',
#  '$99',
#  'Rest',
#  '2021!',
#  '#HorseRacing…',
#  'VIDEO!',
#  'https://t.co/8b8…',
#  'time',
#  'https://t.co/RuTR58vEfY',
#  '#Thi…',
#  'José',
#  'Luis',
#  'Iglesias',
#  '"KILLA"',
#  'Máquina',
#  'del',
#  'Hipismo',
#  'Siempre',
#  'presente',
#  'los',
#  'grandes',
#  'eventos',
#  'Hípicos.',
#  'PHQS',
#  '‘PLATINUM’',
#  'HORSE',
#  'RACING',
#  'https://t.co/owBvYtn4Mi',
#  '#wednesdayracing',
#  'EVERYTHING',
#  'YOU',
#  'NEED',
#  'KNOW',
#  'ABOUT',
#  'BEYER',
#  'FIGURES',
#  'IS',
#  'REVEALED!!!',
#  'https://t.co/ud1RgOkh3a',
#  'MESSIER',
#  'para',
#  'Hat',
#  'Headpiece',
#  '#kentuckyderby',
#  'is',
#  'https://t.co/ltA2VkwD5W',
#  '#w…',
#  'https://t.co/0DwWxAE2NI',
#  '@track_races:',
#  'Trackandraces',
#  'siemp…',
#  '#GULFSTREAM',
#  '#Superfecta',
#  '#h…',
#  '#horseracingtips',
#  '#hors…',
#  'you',
#  'gana',
#  'por',
#  'cuerpos',
#  '(Gr.3).',
#  'Otro',
#  'ejemplar',
#  'inelegible',
#  'obtener',
#  'puntos',
#  'Matching',
#  'Occasion',
#  'Bag',
#  '#KentuckyDerby…',
#  'we',
#  'YEAR',
#  'DATABASE',
#  'STU…',
#  'https://t.co/UfxnzJ6X7Q',
#  '#ThisRacing…',
#  'field',
#  '@ElHombreTTP:',
#  'by',
#  '@Exacta_Box:',
#  'Kentucky',
#  'de',
#  '@ABRLive:',
#  'Silk',
#  '$64.99)',
#  'points',
#  'taking',
#  'Prep',
#  'up',
#  'first',
#  'be',
#  'Do',
#  'about',
#  'today?',
#  'Cheat',
#  'Sheet',
#  'get',
#  'horses',
#  'Here',
#  'Stakes.',
#  '(G3)',
#  '$142.99)',
#  'are',
#  'Large',
#  '$149.49)',
#  'offic…',
#  'go!!',
#  'Give',
#  'please!',
#  '#WITHERS',
#  'Preview',
#  'w/Vinny',
#  'Blond',
#  '@PicksByDynasty!!',
#  'full',
#  'rundown…',
#  'offers',
#  'Sunday',
#  '@santaanitapark',
#  '🌹',
#  'G3',
#  'Shaped',
#  'horse',
#  'racing',
#  'I',
#  'Derby?',
#  'wins',
#  'but',
#  '1999',
#  'Official',
#  '125th',
#  'Running',
#  'Mint',
#  'Julep',
#  'Collectible',
#  'Souvenir',
#  'Glass',
#  '|',
#  '#eBay',
#  'how',
#  'the…',
#  '@BobEh…',
#  'Hoy',
#  'varias',
#  'competencias',
#  'grado',
#  'ruta',
#  'al',
#  'eso',
#  'lo',
#  'puedes',
#  'disfrutar',
#  'desde',
#  'comodidad',
#  'tu',
#  'Talk',
#  '#RobertBLewis',
#  'Vinny',
#  '@PicksByDynasty',
#  '@MichaelHMyers87',
#  'break',
#  'down',
#  'Any',
#  'fans',
#  'there?',
#  '🐎',
#  'Races',
#  'preview',
#  'expert',
#  '@Alex_Dudz_',
#  '💥👇🏻',
#  'Contender?',
#  'Spotlight-',
#  'TIZ',
#  'BOMB',
#  'Question',
#  'likely',
#  'answered',
#  'weekend.',
#  'my',
#  'Canadian-Bred',
#  'Messier',
#  'Romps,',
#  'But',
#  'Will',
#  'He',
#  'Run',
#  'Colt',
#  'lengths',
#  'look',
#  'Bob',
#  'Baffert',
#  '#CANTMISS',
#  '#autographed',
#  'photo',
#  '#jockey',
#  'available',
#  '@beckettmedia',
#  'https://t.co/ltA2VkwD5W…',
#  'https://t.co/qteW3M2eN8…',
#  'https://t.co/UfxnzJ6X7Q…',
#  'YEAR…',
#  'if',
#  'all',
#  'Churchill',
#  'Far',
#  'Turn',
#  '#TheFarTurn',
#  '#thoroughbred',
#  'will',
#  'What',
#  'race',
#  'coming',
#  'preps',
#  'book',
#  'see',
#  'going',
#  '@GulfstreamPark',
#  'اليوم',
#  'سينطلق',
#  'سباقين',
#  'فئة',
#  'في',
#  'امريكا',
#  'تاهليه',
#  'الي',
#  'الـ',
#  'احدهم',
#  'سباق',
#  'تاهيلي',
#  '10–4–2–1',
#  '@killazo3999:',
#  'hogar',
#  'vis…',
#  'Sinamay',
#  '$77.99)',
#  'disappointing',
#  '#…',
#  'Withers',
#  '148th',
#  '@audiohipismo:',
#  'El',
#  'camino',
#  'hacia',
#  'comienza',
#  'este',
#  'sábado',
#  'Gulfstream',
#  'Park',
#  'con',
#  '.',
#  'https://t.co/dc…',
#  '@vegasodds:',
#  'https://t.co…',
#  'Saucer',
#  '$84.49)',
#  '#HorseRacing',
#  '#Gulfstre…',
#  'Jack',
#  'sold',
#  'home',
#  'decor',
#  'items',
#  'featuring',
#  '“Around',
#  'First',
#  'Turn”🏇',
#  'Thank',
#  'buyers!',
#  'https://t.co/7XTHx1u25e…',
#  'https://t.co/BDzFAw7gQi',
#  '@CanadianTbred:',
#  'did',
#  'n…',
#  'but…',
#  'https://t.co/YZHY8ZkKmF',
#  '@chinoooooooooo0:',
#  'Join',
#  '@LazyHorseRC',
#  '@EbisusBay.',
#  '#Horseracing',
#  '#casino',
#  '#nft',
#  '#PlayToEarn',
#  '#NFTutility',
#  '#breeding',
#  '#Cryptocom',
#  '#irlracingtea…',
#  'https://t.co/rFSdQqoVaT',
#  'https://t.co/WrsIaV2XYM',
#  'https://t.co/UFJuGRHx3n',
#  'Live',
#  'hearings',
#  'https://t.co/9GTPkq7Ukv',
#  '#chuchilldowns',
#  '#Kentuckyderby',
#  '#baffert',
#  'These',
#  'selling',
#  'fast!',
#  'If',
#  'considering',
#  'buying',
#  'one,',
#  'recommend',
#  'doing',
#  'it',
#  'soon!!',
#  '#teamoldsmoke',
#  'https://t.co/8QCYrVxCix',
#  'Ascot',
#  '$116.99)',
#  'https://t.co/EWGajg5qJD',
#  'https://t.co/7SV…',
#  'https://t.co/8ElxT0Wyor',
#  'https://t.co/4BCue3tEhS',
#  'https://t.co/jOp98JCcAt',
#  'Can',
#  'White',
#  'Abarrio',
#  'win',
#  'grandsire',
#  'Tapit?',
#  'closer',
#  'hero.',
#  '#kentuckyderby…',
#  'https://t.co/7mCLU8ePeX',
#  '#triplecrown',
#  'Steve',
#  'Cauthen',
#  'authenticat…',
#  'https://t.co/ijZtl7arzQ',
#  'https://t.co/dii1bNVYuI',
#  'https://t.co/jpKNOUwwN8',
#  'https://t.co/sq8bXiNcmH',
#  'https://t.co/k7wB587qOV',
#  'Ray',
#  'Taulbots’',
#  'Blitz',
#  'Superior',
#  'Consistency',
#  'Win',
#  'https://t.co/rW9jqVgEY5',
#  '#wednesdayracing…',
#  'https://t.co/Ce6O5tvhnu',
#  '@PapaBeez',
#  'Specially',
#  'he',
#  'major',
#  'leading',
#  '#kentuckyderby,',
#  'then',
#  'downs',
#  'system',
#  'wi…',
#  'https://t.co/vk8IHnrW9z',
#  '#276',
#  '2-7-22',
#  'https://t.co/5I33TDs9hJ',
#  '#Messier',
#  '#BobBaffert…',
#  'https://t.co/bXO4SJcuU3',
#  'https://t.co/CvR5aqjk9N',
#  'Loops',
#  '$124.79)',
#  'https://t.co/xA4mkLo9Xf',
#  'https://t.co/0Rf1Lfo0md',
#  'https://t.co/dthq0jbnUk',
#  'https://t.co/Z2MlV7HSpO',
#  'https://t.co/gCH6zpGSBV',
#  'el…',
#  'https://t.co/1rs8rtH34o',
#  'Halterman',
#  'have',
#  'official',
#  'RD',
#  'rankings',
#  'later',
#  'week,',
#  'Jared',
#  'sees',
#  'top',
#  '5:',
#  '1.',
#  'Mess…',
#  'https://t.co/EyXqQqoD29',
#  'Que',
#  'clase',
#  'galope',
#  '(Empire',
#  'Maker)',
#  'Jockey:',
#  'John',
#  'R.',
#  'Velazquez',
#  '@ljlmvel',
#  'Trainer:',
#  'su',
#  'antojo…',
#  'https://t.co/aHYLMSGMQQ',
#  'performance',
#  'Messier!',
#  'wow.',
#  'owners',
#  'do',
#  'Baffert’s',
#  'suspension',
#  'holds',
#  'Downs.…',
#  'https://t.co/hav9efX1Zb',
#  'Big',
#  '#SantaAnitaPark',
#  'https://t.co/TRjQTgiNO8',
#  'https://t.co/iAL3d7nRQa',
#  'https://t.co/dp3utfAAII',
#  'Looking',
#  'ahead',
#  'upcoming',
#  'was',
#  'once',
#  'again',
#  'reminded',
#  'silly',
#  '1-mile',
#  'Gotham',
#  'as',
#  'https://t.co/0RVRhKGekU',
#  '@BrianBuckWargo',
#  '@VitalVegas',
#  '@HarrahsVegas',
#  'sportsbook',
#  'still',
#  'favorite',
#  'comfortable',
#  'chairs',
#  'barstools…',
#  'https://t.co/mT7Or5s25j',
#  '@TheLINQ',
#  'whats',
#  'word',
#  'sports',
#  '..',
#  'May',
#  'https://t.co/QQFpTZHylA',
#  'https://t.co/Un4YCeyFf3',
#  'https://t.co/1JuabRuhs8',
#  'https://t.co/03DA0TsGfs',
#  'https://t.co/Ii0uEb8df3',
#  'https://t.co/yrZK1DTOnF',
#  'https://t.co/IDmabw8XwP',
#  'crazy',
#  'goal/dream',
#  'mine',
#  'become',
#  'person',
#  'winning',
#  'car',
#  'owner',
#  '#daytona500',
#  'also',
#  'https://t.co/tQAczcFQlr',
#  'Yet',
#  'another',
#  '5-horse',
#  'prep',
#  '@santaanitapark.',
#  'question',
#  '60-20-10',
#  'split',
#  'races.',
#  'Seem…',
#  'https://t.co/Ko1ssDI5j4',
#  'https://t.co/Xa45rAseUo',
#  'https://t.co/etcMOvRpGG',
#  'https://t.co/ABNNEFZvli',
#  'This',
#  '#LazyHorseRaceClub',
#  'through',
#  '#LHRC',
#  'https://t.co/EIe3OgM7Y2',
#  'Congrats',
#  'bajan',
#  'Saffie',
#  'Joseph',
#  'I’m',
#  'not',
#  'jump',
#  'joy',
#  'yet',
#  'till',
#  'those',
#  'derby',
#  'points,',
#  'anything',
#  'over…',
#  'https://t.co/SRKGTLlZnA',
#  'How',
#  'serious',
#  'Early',
#  'Voting',
#  'now?',
#  'https://t.co/pHlRGivLqP',
#  'Pillbox',
#  '$51.99)',
#  'https://t.co/IqSt5RHc9o',
#  'https://t.co/bDicdPHxcE',
#  'https://t.co/nl5RQ19JOy',
#  'https://t.co/9vrQXO5CeK',
#  'VIDEO!…',
#  'https://t.co/X8FnR5smKZ',
#  'https://t.co/0DwWxAE2NI…',
#  'https://t.co/cpWSiNz9E1',
#  '#HolyBull',
#  'has',
#  'some',
#  'nice',
#  '3yo',
#  'Colts',
#  '1',
#  '1/16',
#  'Main',
#  'Track.',
#  'Pretty',
#  'excited',
#  'on…',
#  'https://t.co/kchFN0WnhI',
#  '@abdalslam_14:',
#  'وسيشارك',
#  'الم…',
#  'وسيشا…',
#  'https://t.co/y3otsVrR8k',
#  'ho…',
#  'https://t.co/CFcRouqi3O',
#  '$129.99)',
#  'https://t.co/D7QxF9bfzt',
#  'https://t.co/9z…',
#  'Jorge',
#  'Velasquez',
#  'authenticated',
#  'your…',
#  'https://t.co/MmxgXbGLLt',
#  'https://t.co/x2gSd0NQm1',
#  'https://t.co/vtC6aPJgee',
#  'https://t.co/IFIRjLo0UC',
#  '@BoatCousins',
#  'more',
#  'tomorrow',
#  '@TheNYRA',
#  '#picks',
#  'https://t.co/KUdJHgz3y0',
#  'ready',
#  'players....derby',
#  'fever',
#  'way',
#  'worse',
#  'than',
#  '#omicron!',
#  'go!',
#  '#holybull',
#  '#Withers…',
#  'https://t.co/jSqZ6snjDg',
#  'Video',
#  'Prep.',
#  'https://t.co/llCIulZT9N',
#  'field…',
#  'https://t.co/SiBRGthdNm',
#  'disappoi…',
#  'https://t.co/b9zcnFvG5U',
#  'https://t.co/SxP1l3swCg',
#  'https://t.co/KOekKPWipn',
#  'Mini',
#  'https://t.co/3OXCRYcxjY',
#  'https://t.co/Rd4e5OyhbR',
#  'time…',
#  'https://t.co/dEfhBl2kMf',
#  '#horseracing…',
#  'https://t.co/5HegSkL5E5',
#  '#GULFSTREAM…',
#  'https://t.co/5qHhh8l8zN',
#  'Did',
#  'someone',
#  'say',
#  'Yes,',
#  'here',
#  'well',
#  'aware',
#  '93',
#  'days',
#  'away!',
#  "We've",
#  'already',
#  'plant…',
#  'https://t.co/bj9CuINHYa',
#  'https://t.co/bg3LDW7qjK',
#  'https://t.co/dL6dPm7bko…',
#  'https://t.co/GMKN2ntRZI',
#  '#275',
#  '2-4-22',
#  'https://t.co/Kq8aua5HRR',
#  '#KyDerby',
#  'https://t.co/mxEqlGTPsb',
#  'https://t.co/I2ssqThu4r…',
#  'https://t.co/qW33eXibxX',
#  'Trackandrace…',
#  'https://t.co/xuYGNRgk2D',
#  '#TrueBLUE',
#  '#KentuckyDerby!',
#  'Aimee',
#  'Fuller',
#  '#Hats',
#  '#StatementJewelry',
#  'https://t.co/NLPdAKXTUN',
#  '#Millinery…',
#  'https://t.co/rphhlZMRdJ',
#  'https://t.co/NlcDd9hxSd',
#  '@lingometro:',
#  'Fry’s',
#  '#Louisville',
#  '#Kentucky',
#  'staple!',
#  'Opened',
#  '1933',
#  'Fry',
#  'people,',
#  'they',
#  'feature',
#  'photos',
#  'prog…',
#  '2022',
#  'Field,',
#  'Odds',
#  'Jockeys',
#  'Trainers',
#  'running',
#  'Grade',
#  '3,',
#  '$250,000',
#  '#Withers',
#  'A…',
#  'https://t.co/mlrUBygQfM']
