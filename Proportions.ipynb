# %% [markdown]
# <a href="https://colab.research.google.com/github/BrendenLatham/Data_Viz/blob/main/Proportions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Proportions

# %% [markdown]
# For this assignment we will be looking at proportions

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pa.read_csv('https://raw.githubusercontent.com/nurfnick/Data_Viz/main/Activity_Dataset_V1.csv')

df.head()
# Out:
#    Unnamed: 0 activity_day    workout_type  distance  time  calories  \
# 0           0   2022-01-01       Freestyle      9.30    77       123
# 1           1   2022-01-01       Freestyle      3.44    96        55
# 2           2   2022-01-01  Indoor Cycling      6.34    85        33
# 3           3   2022-01-01         Walking      7.91    42        82
# 4           4   2022-01-01      Open Water      8.99    36       131
#
#    total_steps  avg_speed  avg_cadence  max_cadence  ... max_pace min_pace  \
# 0          NaN      18.88       168.54       138.30  ...      NaN      NaN
# 1          NaN      29.65       125.92       292.81  ...      NaN      NaN
# 2          NaN      17.85        81.93       323.69  ...      NaN      NaN
# 3       1571.0      22.10        29.63       180.16  ...    28:58    07:58
# 4          NaN      25.83        64.55       342.89  ...      NaN      NaN
#
#   avg_heart_rate  max_heart_rate  min_heart_rate  vo2_max(%)  aerobic(%)  \
# ...

# %% [markdown]
# First I will be creating a pie chart of the workout type

# %%
# function taken from https://stackoverflow.com/questions/53782591/how-to-display-actual-values-instead-of-percentages-on-my-pie-chart-using-matplo
def autopct_format(values):
    def my_format(pct):
        total = sum(values)
        val = int(round(pct*total/100.0))
        return '{v:d}'.format(v=val)
    return my_format
plt.style.use('fivethirtyeight')
plt.pie(x=df.groupby('workout_type').workout_type.agg('count'),labels=df.groupby('workout_type').workout_type.agg('count').index, autopct=autopct_format(df.groupby('workout_type').workout_type.agg('count')))
plt.annotate('Pretty Color',xy=(.75,.25),xytext=(1.2,.6),arrowprops = dict(facecolor = 'red', width = 2, headwidth = 12, headlength = 6))
plt.show()
# print(plt.style.available) to see available color styles

# %% [markdown]
# A pie chart or a bar chart will work for an overview of the data, but in order to dive in further and look at how the data compares over time, a Mosaic Plot might be necessary.
